# %%
import oracledb
import pandas as pd

# %%
pip install sqlalchemy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 12.5 MB/s eta 0:00:0000:010:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
con = oracledb.connect("jaeminiman/1234@localhost:1521/xe")

# %%
df = pd.read_csv('mysql/PL2122_match.csv', encoding = 'euc-kr').iloc[:,1:]
df.head()
# Out:
#    home_shot  away_shot  home_possession  away_possession  home_pass_success  \
# 0         14          5             43.1             56.9                 84
# 1         15         12             34.1             65.9                 79
# 2          9         21             42.4             57.6                 73
# 3         22         10             62.7             37.3                 87
# 4         16          8             61.3             38.7                 82
#
#    away_pass_success  home_dribbles  away_dribbles  home_aerials_won  \
# 0                 86             11              9                 8
# 1                 85             15             13                17
# 2                 83              8              7                25
# 3                 73              5              7                19
# 4                 71              5              6                17
#
#    away_aerials_won  ...  home_own_att  away_own_att  home_total_passes  \
# ...

# %%
df.to_sql(name='match_PL_2122', con=con, if_exists='append',index=False)
# Out:
# /var/folders/0n/d2rdhpkj2lq5h2j83266pz3r0000gn/T/ipykernel_47177/3363054608.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df.to_sql(name='match_PL_2122', con=con, if_exists='append',index=False)
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/io/sql.py:2018, in SQLiteDatabase.execute(self, *args, **kwargs)
#    2017 try:
# -> 2018     cur.execute(*args, **kwargs)
#    2019     return cur
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/oracledb/cursor.py:378, in Cursor.execute(self, statement, parameters, **keyword_parameters)
#     377     impl.bind_one(self, parameters)
# ...
